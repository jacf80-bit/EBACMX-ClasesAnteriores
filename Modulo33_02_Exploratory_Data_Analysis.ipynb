# %% [markdown]
# # Project2: - Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir('/users/yoga7i/Downloads/sales_month_2019')

# %% [markdown]
# Preparación de Datos

# %%
# Generación de un DataFrame maestro a partir de varios archivos
# Utilizando la función read CSV
df1 = pd.read_csv('Sales_January_2019.csv')
df2 = pd.read_csv('Sales_February_2019.csv')
df3 = pd.read_csv('Sales_March_2019.csv')
df4 = pd.read_csv('Sales_April_2019.csv')
df5 = pd.read_csv('Sales_May_2019.csv')
df6 = pd.read_csv('Sales_June_2019.csv')
df7 = pd.read_csv('Sales_July_2019.csv')
df8 = pd.read_csv('Sales_August_2019.csv')
df9 = pd.read_csv('Sales_September_2019.csv')
df10 = pd.read_csv('Sales_October_2019.csv')
df11 = pd.read_csv('Sales_November_2019.csv')
df12 = pd.read_csv('Sales_December_2019.csv')

# %%
df1.sample(5)
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 7437   148315    USB-C Charging Cable                1      11.95
# 4313   145323  AAA Batteries (4-pack)                1       2.99
# 9100   149909  27in 4K Gaming Monitor                1     389.99
# 4939   145926  AAA Batteries (4-pack)                1       2.99
# 3545   144601   AA Batteries (4-pack)                2       3.84
#
#           Order Date                        Purchase Address
# 7437  01/07/19 20:57       438 Cherry St, Portland, ME 04101
# 4313  01/20/19 19:17         493 Center St, Dallas, TX 75001
# 9100  01/26/19 11:14      387 Johnson St, Portland, OR 97035
# 4939  01/10/19 10:42           629 8th St, Seattle, WA 98101
# 3545  01/14/19 21:17  347 Cherry St, New York City, NY 10001

# %%
# Generar un dataser final donde se van a compilar todos los anteriores
df = df1
# Genera un campo de fecha
df['Month'] = '2019-01-01'

# %%
df.sample(5)
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 8892   149710    27in 4K Gaming Monitor                1     389.99
# 2568   143666                    iPhone                1        700
# 4437   145444  Lightning Charging Cable                2      14.95
# 2530   143632      USB-C Charging Cable                1      11.95
# 525    141747          27in FHD Monitor                1     149.99
#
#           Order Date                        Purchase Address       Month
# 8892  01/31/19 18:10  949 Center St, San Francisco, CA 94016  2019-01-01
# 2568  01/20/19 09:22           689 9th St, Atlanta, GA 30301  2019-01-01
# 4437  01/25/19 11:06    379 Park St, San Francisco, CA 94016  2019-01-01
# 2530  01/08/19 08:26       759 Elm St, Los Angeles, CA 90001  2019-01-01
# 525   01/12/19 05:12     160 Ridge St, Los Angeles, CA 90001  2019-01-01

# %%
# February
df = pd.concat([df,df2],ignore_index=True)
df['Month'] = df['Month'].fillna('2019-02-01')
#March
df = pd.concat([df, df3], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-03-01')
#April
df = pd.concat([df, df4], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-04-01')
#May
df = pd.concat([df, df5], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-05-01')
#June
df = pd.concat([df, df6], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-06-01')
#July
df = pd.concat([df, df7], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-07-01')
#August
df = pd.concat([df, df8], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-08-01')
#September
df = pd.concat([df, df9], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-09-01')
#October
df = pd.concat([df, df10], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-10-01')
#November
df = pd.concat([df, df11], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-11-01')
#December
df = pd.concat([df, df12], ignore_index=True)
df['Month'] = df['Month'].fillna('2019-12-01')

# %% [markdown]
# Análisis Básico

# %%
# Ya que esta todo en un DataFrame maestro, verificamos los datos
df.sample(5)
# Out:
#        Order ID             Product Quantity Ordered Price Each  \
# 62429    200798  Macbook Pro Laptop                1       1700
# 91980    228987  LG Washing Machine                1      600.0
# 3238     144312    27in FHD Monitor                1     149.99
# 152612   286961              iPhone                1        700
# 83375    220775        20in Monitor                1     109.99
#
#             Order Date                      Purchase Address       Month
# 62429   05/17/19 08:25   25 13th St, San Francisco, CA 94016  2019-05-01
# 91980   07/29/19 10:31    60 South St, Los Angeles, CA 90001  2019-07-01
# 3238    01/03/19 20:43  563 Wilson St, Los Angeles, CA 90001  2019-01-01
# 152612  11/06/19 17:06        928 10th St, Atlanta, GA 30301  2019-11-01
# 83375   06/04/19 16:00         994 Main St, Austin, TX 73301  2019-06-01

# %%
# Cuenta el número de ventas por mes 
df.groupby('Month')['Month'].count()
# Out:
# Month
# 2019-01-01     9723
# 2019-02-01    12036
# 2019-03-01    15226
# 2019-04-01    18383
# 2019-05-01    16635
# 2019-06-01    13622
# 2019-07-01    14371
# 2019-08-01    12011
# 2019-09-01    11686
# 2019-10-01    20379
# 2019-11-01    17661
# 2019-12-01    25117
# Name: Month, dtype: int64

# %%
# Gráfica del número de ventas por mes
df.groupby('Month')['Month'].count().plot.bar()
# Out:
# <Axes: xlabel='Month'>

# %%
# Hacemos un shape para ver cuantas filas y columnas tiene el DataFrame
df.shape
# Out:
# (186850, 7)

# %%
# Tipos de datos del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   Month             186850 non-null  object
# dtypes: object(7)
# memory usage: 10.0+ MB

# %% [markdown]
# Masajeo de Datos

# %%
# Eliminar nulos
df = df.dropna(how='all')

# %%
df['Order Date']
# Out:
# 0         01/22/19 21:25
# 1         01/28/19 14:15
# 2         01/17/19 13:33
# 3         01/05/19 20:33
# 4         01/25/19 11:59
#                ...
# 186845    12/11/19 20:58
# 186846    12/01/19 12:01
# 186847    12/09/19 06:43
# 186848    12/03/19 10:39
# 186849    12/21/19 21:45
# Name: Order Date, Length: 186850, dtype: object

# %%
# Elimina todas las cadenas especiales para la fecha del pedido
df = df[df['Order Date'].str[0:2] != 'Or']

# %%
# Se detecta que todos los datos son de tipo object por lo que dificulta el análisis
# Se cambia el tipo de datos para facilitar el procesamiento
# Convertir el 'Date' a datetime format
df['Month'] = pd.to_datetime(df['Month'])
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\3633410655.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
# Se verifica los cambios de fechas, se observa que sí existen nulos tenemos 186495 mes y 185950 datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186495 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Month             186495 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 11.4+ MB

# %%
# Se tiene que tener cuidado con las cantidades
df['Quantity Ordered'].unique()
# Out:
# array(['1', '2', '3', '5', '4', nan, '7', '6', '9', '8'], dtype=object)

# %%
# Conversión de las columnas
df['Order ID'] = df['Order ID'].astype('string')
df['Product'] = df['Product'].astype('string')
# Tratamiento de nulos en Quantity Ordered y conversión a numérico
df['Quantity Ordered'] = df['Quantity Ordered'].fillna(0)
df['Quantity Ordered'] = df['Quantity Ordered'].astype('int64')
# Conversión de precio a float
df['Price Each'] = df['Price Each'].astype('float')
# Conversión de Purchase Address como string
df['Purchase Address'] = df['Purchase Address'].astype('string')

# %%
df.dtypes
# Out:
# Order ID            string[python]
# Product             string[python]
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address    string[python]
# Month               datetime64[ns]
# dtype: object

# %%
# Número de datos vacíos por columna, existen 545 nulos en cada columna
missing_values_count = df.isnull().sum()
missing_values_count[0:10]
# Out:
# Order ID            545
# Product             545
# Quantity Ordered      0
# Price Each          545
# Order Date          545
# Purchase Address    545
# Month                 0
# dtype: int64

# %%
# Calcula el % total de datos no existentes
# Cuántos datos totales tenemos, y cuántos missing
total_cells = np.prod(df.shape)
total_missing = missing_values_count.sum()
# Cálculo del porcentaje
percent_missing = (total_missing / total_cells) * 100
print(f'El porcentaje de datos que no existe es:{percent_missing:.2f}%')
# Out:
# El porcentaje de datos que no existe es:0.21%

# %%
# Puedo eliminar todos los datos donde la cantidad sea 0
# Se puede deber a un error del sistema que generó 545 registros de ventas sin haberlas
df[df['Quantity Ordered'] == 0]
# Out:
#        Order ID Product  Quantity Ordered  Price Each Order Date  \
# 664        <NA>    <NA>                 0         NaN        NaT
# 678        <NA>    <NA>                 0         NaN        NaT
# 797        <NA>    <NA>                 0         NaN        NaT
# 876        <NA>    <NA>                 0         NaN        NaT
# 1299       <NA>    <NA>                 0         NaN        NaT
# ...         ...     ...               ...         ...        ...
# 184678     <NA>    <NA>                 0         NaN        NaT
# 184695     <NA>    <NA>                 0         NaN        NaT
# 185042     <NA>    <NA>                 0         NaN        NaT
# 185729     <NA>    <NA>                 0         NaN        NaT
# 186463     <NA>    <NA>                 0         NaN        NaT
#
#        Purchase Address      Month
# 664                <NA> 2019-01-01
# 678                <NA> 2019-01-01
# 797                <NA> 2019-01-01
# 876                <NA> 2019-01-01
# ...

# %%
# Elimina todos los registros donde la orden sea 0
df = df[df['Quantity Ordered'] > 0]

# %%
df.shape
# Out:
# (185950, 7)

# %%
# Número de datos vacíos por columna
missing_values_count = df.isnull().sum()
missing_values_count[0:10]
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# dtype: int64

# %%
# Una vez se tenga limpia la base de nulos, se muestra un describe de las columnas numéricas
# Quitar el formato científico de algunas columnas a dos decimales
pd.options.display.float_format = '{:.2f}'.format
df.describe()
# Out:
#        Quantity Ordered  Price Each                     Order Date  \
# count         185950.00   185950.00                         185950
# mean               1.12      184.40  2019-07-18 21:54:38.887550208
# min                1.00        2.99            2019-01-01 03:07:00
# 25%                1.00       11.95            2019-04-16 21:05:15
# 50%                1.00       14.95            2019-07-17 20:40:30
# 75%                1.00      150.00            2019-10-26 08:14:00
# max                9.00     1700.00            2020-01-01 05:13:00
# std                0.44      332.73                            NaN
#
#                                Month
# count                         185950
# mean   2019-07-03 11:51:07.056735488
# min              2019-01-01 00:00:00
# 25%              2019-04-01 00:00:00
# 50%              2019-07-01 00:00:00
# 75%              2019-10-01 00:00:00
# max              2019-12-01 00:00:00
# std                              NaN

# %%
# Se transpone la tabla
df.describe().T
# Out:
#                      count                           mean  \
# Quantity Ordered 185950.00                           1.12
# Price Each       185950.00                         184.40
# Order Date          185950  2019-07-18 21:54:38.887550208
# Month               185950  2019-07-03 11:51:07.056735488
#
#                                   min                  25%  \
# Quantity Ordered                 1.00                 1.00
# Price Each                       2.99                11.95
# Order Date        2019-01-01 03:07:00  2019-04-16 21:05:15
# Month             2019-01-01 00:00:00  2019-04-01 00:00:00
#
#                                   50%                  75%  \
# Quantity Ordered                 1.00                 1.00
# Price Each                      14.95               150.00
# Order Date        2019-07-17 20:40:30  2019-10-26 08:14:00
# Month             2019-07-01 00:00:00  2019-10-01 00:00:00
#
#                                   max    std
# ...

# %%
# Total de ventas analizadas
df.shape[0]
# Out:
# 185950

# %%
# Para generar la columna zipcode de los datos unidos en address
df['Purchase Address']
# Out:
# 0                944 Walnut St, Boston, MA 02215
# 1               185 Maple St, Portland, OR 97035
# 2          538 Adams St, San Francisco, CA 94016
# 3             738 10th St, Los Angeles, CA 90001
# 4                  387 10th St, Austin, TX 73301
#                            ...
# 186845    14 Madison St, San Francisco, CA 94016
# 186846      549 Willow St, Los Angeles, CA 90001
# 186847          273 Wilson St, Seattle, WA 98101
# 186848            778 River St, Dallas, TX 75001
# 186849    747 Chestnut St, Los Angeles, CA 90001
# Name: Purchase Address, Length: 185950, dtype: string

# %%
df['Purchase Address'].str[-6:]
# Out:
# 0          02215
# 1          97035
# 2          94016
# 3          90001
# 4          73301
#            ...
# 186845     94016
# 186846     90001
# 186847     98101
# 186848     75001
# 186849     90001
# Name: Purchase Address, Length: 185950, dtype: string

# %%
# Se genera la columna zipcode, tomando los últimos 5 dígitos de la dirección
df['zipcode'] = df['Purchase Address'].str[-6:]
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\1839110440.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['zipcode'] = df['Purchase Address'].str[-6:]

# %%
# Total de zipcodes analizados
df['zipcode'].unique()
# Out:
# <StringArray>
# [' 02215', ' 97035', ' 94016', ' 90001', ' 73301', ' 30301', ' 98101',
#  ' 10001', ' 75001', ' 04101']
# Length: 10, dtype: string

# %%
# Cambio el tipo de dato del zipcode a string
df['zipcode'] = df['zipcode'].astype('string')
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\1901793771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['zipcode'] = df['zipcode'].astype('string')

# %%
# Reviso los cambios
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  string
#  1   Product           185950 non-null  string
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  string
#  6   Month             185950 non-null  datetime64[ns]
#  7   zipcode           185950 non-null  string
# dtypes: datetime64[ns](2), float64(1), int64(1), string(4)
# memory usage: 12.8 MB

# %%
# Se cuenta el número de zipcodes
num_zipcodes = df['zipcode'].unique().__len__()
num_zipcodes
# Out:
# 10

# %%
# Número de valores únicos para ver la estructura interna de cada columna qué tan variada es
df.nunique()
# Out:
# Order ID            178437
# Product                 19
# Quantity Ordered         9
# Price Each              17
# Order Date          142395
# Purchase Address    140787
# Month                   12
# zipcode                 10
# dtype: int64

# %%
# Buscar por nulos en el DataFrame
print('Existen',df.isnull().sum().sum(),'valores faltantes')
# Out:
# Existen 0 valores faltantes

# %% [markdown]
# # Análisis de Correlación

# %%
# Gráfico de correlación
plt.Figure(figsize=(12,8))
corr_df = df.select_dtypes(include=['number']).corr(method='pearson')
df_lt = corr_df.where(np.tril(np.ones(corr_df.shape)).astype(bool))
hmap = sns.heatmap(df_lt, cmap='YlGnBu', annot=True)

# %%
# Visualizar columnas y número de columnas
print('Lista de Columnas')
print('--------------------')
print(df.columns)
print(len(df.columns), 'columns')
# Número de columnas ()
cols_num = ['Quantity Ordered', 'Price Each']
# Out:
# Lista de Columnas
# --------------------
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'zipcode'],
#       dtype='object')
# 8 columns

# %%
# Gráfico exploratorio de todas las columnas
sns.displot(df['Quantity Ordered'], kde=False)
sns.displot(df['Price Each'], kde=False)

# %% [markdown]
# Agrupamientos

# %%
# Agrupamiento general por variable Meses ticket promedio
df.groupby(['Month']).mean(numeric_only=True)
# Out:
#             Quantity Ordered  Price Each
# Month
# 2019-01-01              1.12      186.45
# 2019-02-01              1.12      182.74
# 2019-03-01              1.12      184.32
# 2019-04-01              1.12      184.43
# 2019-05-01              1.13      188.90
# 2019-06-01              1.13      189.03
# 2019-07-01              1.12      184.15
# 2019-08-01              1.12      186.53
# 2019-09-01              1.13      179.40
# 2019-10-01              1.12      183.18
# 2019-11-01              1.13      180.88
# 2019-12-01              1.13      183.85

# %%
# Agrupamiento por variable: Product
# La mediana de cada orden es de un producto, con diferentes precios por cada producto
df.groupby(['Product']).mean(numeric_only=True)
# Out:
#                             Quantity Ordered  Price Each
# Product
# 20in Monitor                            1.01      109.99
# 27in 4K Gaming Monitor                  1.00      389.99
# 27in FHD Monitor                        1.01      149.99
# 34in Ultrawide Monitor                  1.00      379.99
# AA Batteries (4-pack)                   1.34        3.84
# AAA Batteries (4-pack)                  1.50        2.99
# Apple Airpods Headphones                1.01      150.00
# Bose SoundSport Headphones              1.01       99.99
# Flatscreen TV                           1.00      300.00
# Google Phone                            1.00      600.00
# LG Dryer                                1.00      600.00
# LG Washing Machine                      1.00      600.00
# Lightning Charging Cable                1.07       14.95
# Macbook Pro Laptop                      1.00     1700.00
# ThinkPad Laptop                         1.00      999.99
# ...

# %%
# Gráfico 
df.groupby(['Product']).median(numeric_only=True).sort_values(by='Price Each').plot.bar()
# Out:
# <Axes: xlabel='Product'>

# %%
# Se generan grupos de items: Monitor, Baterias, Headphones, etc
# Primero se añade una columna en blanco
df['ProductGroup'] = ''

# %%
# Luego se asignan los grupos a cada variable
df.loc[(df['Product'] == '20in Monitor'), 'ProductGroup'] = 'Monitor'
df.loc[(df['Product'] == '27in 4K Gaming Monitor'), 'ProductGroup'] = 'Monitor'
df.loc[(df['Product'] == '27in FHD Monitor'), 'ProductGroup'] = 'Monitor'
df.loc[(df['Product'] == '34in Ultrawide Monitor'), 'ProductGroup'] = 'Monitor'
df.loc[(df['Product'] == 'AA Batteries (4-pack)'), 'ProductGroup'] = 'Batteries'
df.loc[(df['Product'] == 'AAA Batteries (4-pack)'), 'ProductGroup'] = 'Batteries'
df.loc[(df['Product'] == 'Apple Airpods Headphones'), 'ProductGroup'] = 'Headphones'
df.loc[(df['Product'] == 'Bose SoundSport Headphones'), 'ProductGroup'] = 'Headphones'
df.loc[(df['Product'] == 'Flatscreen TV'), 'ProductGroup'] = 'Monitor'
df.loc[(df['Product'] == 'Google Phone'), 'ProductGroup'] = 'Phones'
df.loc[(df['Product'] == 'LG Dryer'), 'ProductGroup'] = 'Other'
df.loc[(df['Product'] == 'LG Washing Machine'), 'ProductGroup'] = 'Other'
df.loc[(df['Product'] == 'Lightning Charging Cable'), 'ProductGroup'] = 'Cables'
df.loc[(df['Product'] == 'Macbook Pro Laptop'), 'ProductGroup'] = 'Laptops'
df.loc[(df['Product'] == 'ThinkPad Laptop'), 'ProductGroup'] = 'Laptops'
df.loc[(df['Product'] == 'USB-C Charging Cable'), 'ProductGroup'] = 'Cables'
df.loc[(df['Product'] == 'Vareebadd Phone'), 'ProductGroup'] = 'Phones'
df.loc[(df['Product'] == 'Wired Headphones'), 'ProductGroup'] = 'Headphones'
df.loc[(df['Product'] == 'iPhone'), 'ProductGroup'] = 'Phones'

# %%
# Agrupamiento general por variables: ProductGroup
df.groupby(['ProductGroup']).median(numeric_only=True)
# Out:
#               Quantity Ordered  Price Each  Total Sales
# ProductGroup
# Batteries                 1.00        2.99         3.84
# Cables                    1.00       11.95        14.95
# Headphones                1.00       99.99        99.99
# Laptops                   1.00     1700.00      1700.00
# Monitor                   1.00      300.00       300.00
# Other                     1.00      600.00       600.00
# Phones                    1.00      600.00       600.00

# %%
# Análisis por zipcode
df.groupby(['zipcode']).mean(numeric_only=True)
# Out:
#          Quantity Ordered  Price Each
# zipcode
# 02215                1.13      182.47
# 04101                1.12      182.15
# 10001                1.12      186.34
# 30301                1.12      186.81
# 73301                1.13      182.72
# 75001                1.13      185.74
# 90001                1.12      183.13
# 94016                1.12      183.57
# 97035                1.13      185.87
# 98101                1.12      185.53

# %%
# Agrupamiento por productgroup y zipcode, cuanto compra la gente segun el zipcode cada producto
df.groupby(['ProductGroup','zipcode']).mean(numeric_only=True)
# Out:
#                       Quantity Ordered  Price Each  Total Sales
# ProductGroup zipcode
# Batteries    02215                1.43        3.41         4.86
#              04101                1.41        3.46         4.84
#              10001                1.42        3.41         4.82
#              30301                1.40        3.42         4.75
#              73301                1.43        3.41         4.84
# ...                                ...         ...          ...
# Phones       75001                1.00      614.08       614.08
#              90001                1.00      621.19       622.29
#              94016                1.00      619.21       620.04
#              97035                1.00      620.66       621.59
#              98101                1.00      616.15       616.75
#
# [70 rows x 3 columns]

# %% [markdown]
# Análisis Bivariado

# %%
# Análisis bivariado número de ventas por mes y por zipcode
pd.crosstab(df['zipcode'],df['Month'])
# Out:
# Month    2019-01-01  2019-02-01  2019-03-01  2019-04-01  2019-05-01  \
# zipcode
# 02215          1048        1256        1648        1918        1800
# 04101           123         177         188         243         222
# 10001          1303        1611        1981        2434        2268
# 30301           786         936        1245        1472        1331
# 73301           527         626         840         973         839
# 75001           785         981        1202        1350        1420
# 90001          1529        1901        2456        3026        2568
# 94016          2354        2912        3597        4437        3921
# 97035           500         659         795         994         944
# 98101           726         927        1202        1442        1241
#
# Month    2019-06-01  2019-07-01  2019-08-01  2019-09-01  2019-10-01  \
# zipcode
# 02215          1392        1552        1245        1283        2176
# ...

# %%
# La misma tabla pero con gráfico de líneas
pd.crosstab(df['Month'],df['zipcode']).plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Descubrimientos (InSights)

# %%
# Generamos un campo que no existe el total de ventas
df['Total Sales'] = df['Quantity Ordered'] * df['Price Each']

# %%
df.sample(5)
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 45602    184789  Bose SoundSport Headphones                 1       99.99
# 17086    157510        USB-C Charging Cable                 1       11.95
# 110370   246599       AA Batteries (4-pack)                 1        3.84
# 101351   237973      AAA Batteries (4-pack)                 1        2.99
# 145429   280091  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address      Month  \
# 45602  2019-04-26 21:23:00            393 1st St, Dallas, TX 75001 2019-04-01
# 17086  2019-02-28 15:16:00   747 River St, San Francisco, CA 94016 2019-02-01
# 110370 2019-08-13 07:39:00      971 Jefferson St, Boston, MA 02215 2019-08-01
# 101351 2019-08-31 08:55:00       704 6th St, Los Angeles, CA 90001 2019-08-01
# 145429 2019-11-27 17:20:00  715 Spruce St, New York City, NY 10001 2019-11-01
#
#        zipcode ProductGroup  Total Sales
# ...

# %%
# Más descubrimientos: Top productos por ventas, productos con mayor crecimiento,
# vistas de ventas de productos por cada uno de ellos
# Producto con mayor y menor crecimiento
# Primero obtenemos las ventas por producto
pd.crosstab(df['ProductGroup'], df['Month'], values=df['Total Sales'], aggfunc='sum', margins=True)
# Out:
# Month         2019-01-01 00:00:00  2019-02-01 00:00:00  2019-03-01 00:00:00  \
# ProductGroup
# Batteries                10244.04             12571.49             15918.66
# Cables                   32551.25             42145.45             51262.05
# Headphones              200954.60            251712.74            337765.41
# Laptops                 616497.83            744497.23            989996.56
# Monitor                 400387.40            518254.33            621720.62
# Other                    48600.00             46800.00             68400.00
# Phones                  506100.00            587500.00            724000.00
# All                    1815335.12           2203481.24           2809063.30
#
# Month         2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00  \
# ProductGroup
# Batteries                19615.12             17914.41             14503.20
# Cables                   62572.95             55775.70             45263.80
# ...

# %%
# Validamos las ventas de enero
df[df['Month'] == '2019-01-01']['Total Sales'].sum()
# Out:
# np.float64(1815335.12)

# %%
# Ventas de enero y 20in Monitor
df[(df['Month'] == '2019-01-01') & (df['Product'] == '20in Monitor')]['Total Sales'].sum()
# Out:
# np.float64(23647.85)

# %%
# Se puede generar una tabla pivote con ventas por grupo de producto y mes
pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).fillna(0).reset_index()
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\3227409839.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).fillna(0).reset_index()
# ProductGroup      Month  Batteries   Cables  Headphones    Laptops    Monitor  \
# 0            2019-01-01   10244.04 32551.25   200954.60  616497.83  400387.40
# 1            2019-02-01   12571.49 42145.45   251712.74  744497.23  518254.33
# 2            2019-03-01   15918.66 51262.05   337765.41  989996.56  621720.62
# 3            2019-04-01   19615.12 62572.95   382308.46 1165496.08  760166.50
# 4            2019-05-01   17914.41 55775.70   343719.51 1155096.32  678378.86
# 5            2019-06-01   14503.20 45263.80   291137.40  920196.85  579392.05
# ...

# %%
# Nuevo DataFrame de ventas por producto por mes
dfsales = pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['Product'], aggfunc=sum).fillna(0).reset_index()
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\1620112511.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   dfsales = pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['Product'], aggfunc=sum).fillna(0).reset_index()

# %%
# Cuadro con el porcentaje de ventas de cada producto por mes
dfsales[list(dfsales.columns)[1:20]].pct_change()
# Out:
# Product  20in Monitor  27in 4K Gaming Monitor  27in FHD Monitor  \
# 0                 NaN                     NaN               NaN
# 1                0.14                    0.37              0.13
# 2                0.33                    0.12              0.28
# 3                0.21                    0.18              0.21
# 4               -0.14                   -0.04             -0.07
# 5               -0.06                   -0.17             -0.17
# 6                0.02                    0.07              0.07
# 7               -0.20                   -0.09             -0.19
# 8                0.06                   -0.13             -0.02
# 9                0.55                    0.89              0.64
# 10              -0.02                   -0.20             -0.09
# 11               0.36                    0.49              0.34
#
# Product  34in Ultrawide Monitor  AA Batteries (4-pack)  \
# 0                           NaN                    NaN
# ...

# %%
dfsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Month                       12 non-null     datetime64[ns]
#  1   20in Monitor                12 non-null     float64
#  2   27in 4K Gaming Monitor      12 non-null     float64
#  3   27in FHD Monitor            12 non-null     float64
#  4   34in Ultrawide Monitor      12 non-null     float64
#  5   AA Batteries (4-pack)       12 non-null     float64
#  6   AAA Batteries (4-pack)      12 non-null     float64
#  7   Apple Airpods Headphones    12 non-null     float64
#  8   Bose SoundSport Headphones  12 non-null     float64
#  9   Flatscreen TV               12 non-null     float64
#  10  Google Phone                12 non-null     float64
#  11  LG Dryer                    12 non-null     float64
#  12  LG Washing Machine          12 non-null     float64
# ...

# %%
# Se obtienen los 5 productos con mayor crecimiento promedio del ultimo año
dfsalespct = dfsales[list(dfsales.columns)[1:20]].pct_change()

# %%
dfsalespct.mean().sort_values(ascending=False)
# Out:
# Product
# 27in 4K Gaming Monitor       0.14
# LG Dryer                     0.13
# 34in Ultrawide Monitor       0.13
# Macbook Pro Laptop           0.13
# Bose SoundSport Headphones   0.13
# Lightning Charging Cable     0.13
# Flatscreen TV                0.13
# AAA Batteries (4-pack)       0.12
# ThinkPad Laptop              0.12
# Wired Headphones             0.12
# AA Batteries (4-pack)        0.12
# USB-C Charging Cable         0.12
# Apple Airpods Headphones     0.12
# 20in Monitor                 0.11
# iPhone                       0.11
# Vareebadd Phone              0.11
# Google Phone                 0.11
# 27in FHD Monitor             0.10
# LG Washing Machine           0.09
# dtype: float64

# %%
# Qué zipcode ha tenido el mayor crecimiento en ventas
# Aplicamos la misma metodología que con productos
pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['zipcode'], aggfunc=sum).fillna(0).reset_index()
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\1206930588.py:3: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['zipcode'], aggfunc=sum).fillna(0).reset_index()
# zipcode      Month     02215    04101     10001     30301     73301     75001  \
# 0       2019-01-01 199776.55 22708.80 259250.67 149163.38  87587.08 143465.50
# 1       2019-02-01 215796.39 29845.49 305396.20 176566.45 108790.39 184950.05
# 2       2019-03-01 301063.55 30516.29 370198.22 231811.37 154546.28 222976.68
# 3       2019-04-01 353880.16 42536.49 446587.78 284454.92 172683.59 252840.47
# 4       2019-05-01 327687.88 57978.76 436418.35 239262.96 160745.21 266379.49
# 5       2019-06-01 254859.87 30025.33 323874.60 219395.51 143971.20 188897.70
# ...

# %%
# Tabla de ventas por zipcode
sales_zipcode = pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['zipcode'], aggfunc=sum).fillna(0).reset_index()
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\1996194532.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   sales_zipcode = pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['zipcode'], aggfunc=sum).fillna(0).reset_index()

# %%
# Arma la tabla con los porcentajes
sales_zipcodepct = sales_zipcode[list(sales_zipcode.columns)[1:11]].pct_change()

# %%
sales_zipcodepct.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_17d20_row0_col0, #T_17d20_row0_col1, #T_17d20_row0_col2, #T_17d20_row0_col3, #T_17d20_row0_col4, #T_17d20_row0_col5, #T_17d20_row0_col6, #T_17d20_row0_col7, #T_17d20_row0_col8, #T_17d20_row0_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_17d20_row1_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_17d20_row1_col1, #T_17d20_row11_col9 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_17d20_row1_col2, #T_17d20_row11_col4 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_17d20_row1_col3, #T_17d20_row2_col1, #T_17d20_row3_col9 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_17d20_row1_col4 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_17d20_row1_col5 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_17d20_row1_col6, #T_17d20_row2_col9, #T_17d20_row3_col8, #T_17d20_row6_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_17d20_row1_col7 {
# ...

# %%
sales_zipcodepct
# Out:
# zipcode  02215  04101  10001  30301  73301  75001  90001  94016  97035  98101
# 0          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1         0.08   0.31   0.18   0.18   0.24   0.29   0.19   0.27   0.30   0.22
# 2         0.40   0.02   0.21   0.31   0.42   0.21   0.26   0.26   0.30   0.28
# 3         0.18   0.39   0.21   0.23   0.12   0.13   0.28   0.18   0.27   0.26
# 4        -0.07   0.36  -0.02  -0.16  -0.07   0.05  -0.09  -0.05  -0.13  -0.23
# 5        -0.22  -0.48  -0.26  -0.08  -0.10  -0.29  -0.10  -0.21  -0.19   0.01
# 6         0.14   0.10   0.10  -0.03   0.04   0.11  -0.12   0.05   0.03  -0.01
# 7        -0.18   0.07  -0.15  -0.20  -0.16  -0.15  -0.13  -0.16  -0.19  -0.11
# 8         0.03  -0.19  -0.01   0.01  -0.15  -0.09   0.03  -0.14  -0.11  -0.18
# 9         0.48   0.82   0.61   0.79   0.90   0.97   0.73   0.86   0.94   1.03
# 10       -0.04  -0.34  -0.12  -0.10  -0.16  -0.23  -0.18  -0.12  -0.14  -0.21
# ...

# %%
# Se obtienen los zipcodes con mayor crecimiento
sales_zipcodepct.mean().sort_values(ascending=False)
# Out:
# zipcode
# 98101   0.15
# 04101   0.14
# 75001   0.14
# 97035   0.14
# 73301   0.13
# 94016   0.13
# 10001   0.12
# 30301   0.11
# 02215   0.11
# 90001   0.11
# dtype: float64

# %%
# Qué tipo de producto ha tenido el mayor crecimiento según tipo de producto
pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).fillna(0).reset_index()
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\4289581108.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).fillna(0).reset_index()
# ProductGroup      Month  Batteries   Cables  Headphones    Laptops    Monitor  \
# 0            2019-01-01   10244.04 32551.25   200954.60  616497.83  400387.40
# 1            2019-02-01   12571.49 42145.45   251712.74  744497.23  518254.33
# 2            2019-03-01   15918.66 51262.05   337765.41  989996.56  621720.62
# 3            2019-04-01   19615.12 62572.95   382308.46 1165496.08  760166.50
# 4            2019-05-01   17914.41 55775.70   343719.51 1155096.32  678378.86
# 5            2019-06-01   14503.20 45263.80   291137.40  920196.85  579392.05
# ...

# %%
sales_prodgroup = pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).fillna(0).reset_index()
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\1992766295.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   sales_prodgroup = pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).fillna(0).reset_index()

# %%
sales_prodgrouppct = sales_prodgroup[list(sales_prodgroup.columns)[1:9]].pct_change()

# %%
# Se obtienen los 5 product group con mayor crecimiento
sales_prodgrouppct.mean().sort_values(ascending=False)
# Out:
# ProductGroup
# Laptops      0.13
# Monitor      0.13
# Cables       0.12
# Headphones   0.12
# Batteries    0.12
# Phones       0.11
# Other        0.10
# dtype: float64

# %%
# Series de tiempo: Ventas por productgroup en todo el tiempo de la serie
pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).plot()
# Out:
# C:\Users\Yoga7i\AppData\Local\Temp\ipykernel_21992\464911418.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df, values='Total Sales', index=['Month'], columns=['ProductGroup'], aggfunc=sum).plot()
# <Axes: xlabel='Month'>

# %%
# Ventas de los top 5 productos de los últimos 4 meses
# Top 5 de ventas por producto de todos los tiempos / sin filtro meses
df.groupby(['Product']).sum(numeric_only=True)['Total Sales'].sort_values(ascending=False).head(5)
# Out:
# Product
# Macbook Pro Laptop       8037600.00
# iPhone                   4794300.00
# ThinkPad Laptop          4129958.70
# Google Phone             3319200.00
# 27in 4K Gaming Monitor   2435097.56
# Name: Total Sales, dtype: float64

# %%
# Una forma simple de calcular los últimos 4 meses es poner una marca en las transacciones de esos meses
df['Flag4m'] = 0

# %%
df.sample(5)
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 33222    172956      USB-C Charging Cable                 1       11.95
# 91882    228892  Lightning Charging Cable                 1       14.95
# 79496    217057             Flatscreen TV                 1      300.00
# 114765   250797      USB-C Charging Cable                 1       11.95
# 42186    181526                  LG Dryer                 1      600.00
#
#                 Order Date                      Purchase Address      Month  \
# 33222  2019-03-16 12:08:00      989 Spruce St, Atlanta, GA 30301 2019-03-01
# 91882  2019-07-07 14:23:00     483 Cherry St, Portland, OR 97035 2019-07-01
# 79496  2019-06-28 13:24:00     1 5th St, San Francisco, CA 94016 2019-06-01
# 114765 2019-09-24 21:51:00    885 Hill St, Los Angeles, CA 90001 2019-09-01
# 42186  2019-04-17 00:23:00  874 Hill St, San Francisco, CA 94016 2019-04-01
#
#        zipcode ProductGroup  Total Sales  Flag4m
# ...

# %%
# Actualiza la marca de los 4 meses
df.loc[df.Month == '2019-12-01','Flag4m'] = 1
df.loc[df.Month == '2019-11-01','Flag4m'] = 1
df.loc[df.Month == '2019-10-01','Flag4m'] = 1
df.loc[df.Month == '2019-09-01','Flag4m'] = 1

# %%
# Hago un DataFrame de los últimos 4 meses
df4m = df[df['Flag4m'] == 1]

# %%
print('Listado de ventas por producto de los últimos 4 meses')
print('------------------------------------------------------')
df4m.groupby(['Product']).sum(numeric_only=True)['Total Sales'].sort_values(ascending=False).head(10)
# Out:
# Listado de ventas por producto de los últimos 4 meses
# ------------------------------------------------------
# Product
# Macbook Pro Laptop           3224900.00
# iPhone                       1880200.00
# ThinkPad Laptop              1623983.76
# Google Phone                 1288200.00
# 27in 4K Gaming Monitor        992134.56
# Apple Airpods Headphones      934650.00
# 34in Ultrawide Monitor        930595.51
# Flatscreen TV                 583500.00
# Bose SoundSport Headphones    537046.29
# 27in FHD Monitor              443520.43
# Name: Total Sales, dtype: float64

# %%
# Gráfica de barras 
df4m.groupby(['Product']).sum(numeric_only=True)['Total Sales'].sort_values(ascending=False).head(10).plot.bar()
# Out:
# <Axes: xlabel='Product'>

# %%
# Cambio para GitHub
a = 5
b = 8
c = a * b
print(c)
# Out:
# 40

# %%
# Generación de un cambio en un archivo local del repositorio para hacer luego un Commit + Push
d = 8
e = 7
f = d * e
print(f)
